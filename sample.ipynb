# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A53056/manaswini-dav/blob/main/sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# code on lists

# %%
my_list = [1, 2, "three", 4.0, True]
print("List:", my_list)
# Out:
# List: [1, 2, 'three', 4.0, True]

# %% [markdown]
# code on tuple

# %%
my_tuple = (10, "twenty", 30.5, False)
print("Tuple:", my_tuple)
# Out:
# Tuple: (10, 'twenty', 30.5, False)

# %% [markdown]
# code on dictionary

# %%
my_dictionary = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}
print("Dictionary:", my_dictionary)
# Out:
# Dictionary: {'name': 'Alice', 'age': 30, 'city': 'New York'}
